# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
url = "https://www.zalando.fr/api/catalog/articles?categories=femme&limit=84&offset=0"

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize
from urllib.request import urlopen

# %%
#We already Imported the pertinent libraries above. Furthermore, initial API endpoint URL has been established as well.

#3. Now let's make a request to obtain data from the first page. 
response = urlopen(url)
results = json.load(response)

#Flattened data can be found here. 
flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
# <ipython-input-3-1166db117814>:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# <ipython-input-3-1166db117814>:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data1 = json_normalize(flattened_data.articles[0])
#               sku                                               name  \
# 0   NI111A0PV-A11  AIR FORCE 1 PIXEL - Baskets basses - white/bla...
# 1   PO252E00N-B11             CLASSIC SPORT - Casquette - beige/blue
# 2   PU141A0EN-Q11      MUSE METAL - Baskets basses - black/rose gold
# 3   ES741E0E4-Q11                         Pantalon classique - black
# 4   AD541E1HZ-Q11                             Collants - black/white
# ..            ...                                                ...
# 79  PU141E0OK-Q11  PAMELA REIF X PUMA MID WAIST LEGGINGS - Collan...
# 80  RED31J01E-S11  MIRACLE COMPLEXION SPONGE 2 PACK BASE - Beauty...
# 81  EV451K021-O11                         Lunettes de soleil - brown
# 82  LA211A08Z-A11  CARNABY EVO 118 6 SPW  - Baskets basses - whit...
# 83  EV451K021-Q11                         Lunettes de soleil - black
#
#                                                 sizes  \
# 0   [35.5, 36, 36.5, 37.5, 38, 38.5, 39, 40, 40.5,...
# 1                                          [One Size]
# 2        [35.5, 36, 37, 37.5, 38, 38.5, 39, 40, 40.5]
# 3                             [S, M, L, XL, XXL, 3XL]
# 4                              [XXS, XS, S, M, L, XL]
# ..                                                ...
# 79                                  [XS, S, M, L, XL]
# 80                                                 []
# 81                                         [One Size]
# 82  [35.5, 36, 37, 37.5, 38, 39, 39.5, 40, 40.5, 4...
# 83                                         [One Size]
#
#                                               url_key  \
# 0   nike-sportswear-air-force-1-pixel-baskets-bass...
# 1   polo-ralph-lauren-classic-sport-casquette-po25...
# 2   puma-muse-metal-baskets-basses-blackrose-gold-...
# 3   esprit-sports-pantalon-classique-black-es741e0...
# 4   adidas-performance-loungewear-essentials-3-str...
# ..                                                ...
# 79  puma-mid-waist-leggings-collants-black-pu141e0...
# 80  real-techniques-2-pack-miracle-complexion-spon...
# 81  evenandodd-lunettes-de-soleil-brown-ev451k021-o11
# 82  lacoste-carnaby-evo-118-6-spw-baskets-basses-l...
# 83  evenandodd-lunettes-de-soleil-black-ev451k021-q11
#
#                                                 media          brand_name  \
# 0   [{'path': 'spp-media-p1/e7bb7fe54f7d3a0a85f38a...     Nike Sportswear
# 1   [{'path': 'spp-media-p1/a9ae6518dfcb3ec78dba9e...   Polo Ralph Lauren
# 2   [{'path': 'spp-media-p1/78c2fa2f264739d6b581da...                Puma
# 3   [{'path': 'spp-media-p1/9e8c99e520da30459618be...       Esprit Sports
# 4   [{'path': 'spp-media-p1/71397f7ff171480a807373...  adidas Performance
# ..                                                ...                 ...
# 79  [{'path': 'spp-media-p1/70e8b28f5f514a958cfa8b...                Puma
# 80  [{'path': 'spp-media-p1/c7fb530662473351968e63...     Real Techniques
# 81  [{'path': 'spp-media-p1/1148db5bfaea301d896cf7...            Even&Odd
# 82  [{'path': 'spp-media-p1/952db53669fe397abed37f...             Lacoste
# 83  [{'path': 'spp-media-p1/71f4f255c63f3ab4a7439c...            Even&Odd
#
#     is_premium family_articles  \
# 0        False              []
# 1         True              []
# 2        False              []
# 3        False              []
# 4        False              []
# ..         ...             ...
# 79       False              []
# 80       False              []
# 81       False              []
# 82       False              []
# 83       False              []
#
#                                                 flags product_group  \
# 0                                                  []          shoe
# 1                                                  []   accessoires
# 2   [{'key': 'discountRate', 'value': '-30%', 'tra...          shoe
# 3   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing
# 4   [{'key': 'csr', 'value': 'Éco-responsabilité',...      clothing
# ..                                                ...           ...
# 79  [{'key': 'new', 'value': 'Nouveau', 'tracking_...      clothing
# 80                                                 []        beauty
# 81  [{'key': 'csr', 'value': 'Éco-responsabilité',...   accessoires
# 82                                                 []          shoe
# 83  [{'key': 'csr', 'value': 'Éco-responsabilité',...   accessoires
#
#                                               outfits  \
# 0   [{'id': '9sh49LvkS1K', 'url_key': '/outfits/9s...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#                                     delivery_promises price.original  \
# 0                                                  []      109,95  €
# 1                                                  []       34,95  €
# 2                                                  []       90,00  €
# 3                                                  []       39,99  €
# 4                                                  []       29,95  €
# ..                                                ...            ...
# 79                                                 []       69,95  €
# 80                                                 []       10,95  €
# 81  [{'key': 'slow_delivery_flag', 'label': 'Livra...        9,99  €
# 82                                                 []      104,95  €
# 83                                                 []        9,99  €
#
#    price.promotional  price.has_different_prices  \
# 0          109,95  €                       False
# 1           34,95  €                       False
# 2           63,00  €                       False
# 3           31,99  €                       False
# 4           29,95  €                       False
# ..               ...                         ...
# 79          69,95  €                       False
# 80          10,95  €                       False
# 81           9,99  €                       False
# 82         104,95  €                       False
# 83           9,99  €                       False
#
#     price.has_different_original_prices  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
# ..                                  ...
# 79                                False
# 80                                False
# 81                                False
# 82                                False
# 83                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only amount price.base_price
# 0                                       False    NaN              NaN
# 1                                       False    NaN              NaN
# 2                                       False    NaN              NaN
# 3                                       False    NaN              NaN
# 4                                       False    NaN              NaN
# ..                                        ...    ...              ...
# 79                                      False    NaN              NaN
# 80                                      False    NaN              NaN
# 81                                      False    NaN              NaN
# 82                                      False    NaN              NaN
# 83                                      False    NaN              NaN
#
# [84 rows x 20 columns]

# %%
# Get the total number of pages
total_pages=results['pagination']['page_count']

# Your code
df=pd.DataFrame()
for i in range(total_pages):
    k=84*i
    url=f'https://www.zalando.fr/api/catalog/articles?categories=promo-enfant&limit=84&offset={k}&sort=sale'
    response = urlopen(url)
    results = json.load(response)
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    flattened_data1=flattened_data1.set_index('sku')
    df = df.append(flattened_data1)

df

# %%
#6. Finally, let's print the data we just got. 
df

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
#1. Extracting the trending brand from our df.
df.brand_name.value_counts().index[0]

# %%
#2. Extracting the product with the highest discount. 

#Our data is still text. Let's convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

#Defining a Discount Ammount Column to later examine which product has the highest discount. 
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

#Group our SKUs by the ammount of money discounted from the original price.
total_disc=df1.groupby(['name']).sum().discount_amount

# %%
#Sort every SKU by ascending order and show the article with the most discount applied to it. 
total_disc.sort_values(ascending=False).index[0]

# %%
#3. Getting the sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

#Let's first define a column named sum_discounted_prices.
sum_discounted_prices = df['price.promotional'].astype(float).sum()

#Then we'll define a column named sum_original_prices.
sum_original_prices = df['price.original'].astype(float).sum()

#Finally, let's make the ratio. 
ratio = sum_discounted_prices/sum_original_prices
print('The sum of discounts of all goods is: {:.2%}'.format(ratio))
