# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
url = https://www.zalando.fr/promo-homme/?p=2
# Out:
#   File "<ipython-input-16-dc58ac0f3abc>", line 1
#     url = https://www.zalando.fr/promo-homme/?p=2
#                ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}

# %%
#We already Imported the pertinent libraries above. Furthermore, initial API endpoint URL has been established as well.

#3. Now let's make a request to obtain data from the first page. 
response = requests.get(url,headers=headers)
results = response.json()

#Flattened data can be found here. 
flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
# <ipython-input-14-445650ea72f9>:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# <ipython-input-14-445650ea72f9>:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data1 = json_normalize(flattened_data.articles[0])
#               sku                                               name  \
# 0   TO222D0T6-K12                        Chemise - sky blue chambray
# 1   TO722T03L-N11                    Veste légère - faded moss green
# 2   CB952L0I5-D11  MOLTEN DISC HOOP AND STUD EARRINGS - Boucles d...
# 3   JA222O3EY-M11  JCOSHAWN TEE CREW NECK - T-shirt imprimé - dee...
# 4   A0112M02U-Q11         UMILIRI FLEX - Chaussures à lacets - black
# ..            ...                                                ...
# 79  DH022A036-K11                   CHECK SUIT - Costume - dark blue
# 80  WF522O0C9-M11                            T-shirt basique - green
# 81  DEZ22E088-Q11                        Pantalon cargo - anthracite
# 82  KN222T00P-K11  LAKE LONG RAIN JACKET VEGAN - Veste imperméabl...
# 83  BL522S050-C11                    HENRY - Sweatshirt - pewter mix
#
#                                          sizes  \
# 0                               [XL, XXL, 3XL]
# 1                       [XS, S, M, L, XL, XXL]
# 2                                   [One Size]
# 3                                [XS, S, M, L]
# 4                 [40, 41, 42, 43, 44, 45, 46]
# ..                                         ...
# 79  [44, 46, 48, 50, 52, 54, 94, 98, 102, 106]
# 80                 [XS, S, M, L, XL, XXL, 3XL]
# 81                    [28, 30, 32, 34, 36, 38]
# 82                      [XS, S, M, L, XL, XXL]
# 83                     [S, M, L, XL, XXL, 3XL]
#
#                                               url_key  \
# 0   tom-tailor-chemise-sky-blue-chambray-to222d0t6...
# 1   tom-tailor-denim-light-summer-hoody-veste-lege...
# 2   icon-brand-molten-disc-hoop-and-stud-earrings-...
# 3   jack-and-jones-jcoshawn-tee-crew-neck-t-shirt-...
# 4   aldo-umiliri-flex-chaussures-a-lacets-black-a0...
# ..                                                ...
# 79  isaac-dewhirst-check-suit-costume-dark-blue-dh...
# 80     we-fashion-t-shirt-basique-green-wf522o0c9-m11
# 81    defacto-pantalon-cargo-anthracite-dez22e088-q11
# 82  knowledgecotton-apparel-lake-long-rain-jacket-...
# 83    blend-sweatshirt-henry-sweatshirt-bl522s050-c11
#
#                                                 media  \
# 0   [{'path': 'spp-media-p1/a653f74b7d1b41738e4676...
# 1   [{'path': 'spp-media-p1/89e59c54c2293a66a2d6a0...
# 2   [{'path': 'spp-media-p1/7930335eacd74153be4580...
# 3   [{'path': 'spp-media-p1/5035fe425779359aa6726b...
# 4   [{'path': 'spp-media-p1/8427695cfb784d1ab96c55...
# ..                                                ...
# 79  [{'path': 'spp-media-p1/36f33513f74d4fd5ab4602...
# 80  [{'path': 'spp-media-p1/d3907a5061a73780a533a6...
# 81  [{'path': 'spp-media-p1/7859431f8e7f4e798c0285...
# 82  [{'path': 'spp-media-p1/e29955f283c042b7a2fa6c...
# 83  [{'path': 'spp-media-p1/d6199ce4c0ec316280bdcf...
#
#                  brand_name  is_premium  \
# 0                TOM TAILOR       False
# 1          TOM TAILOR DENIM       False
# 2                Icon Brand       False
# 3              Jack & Jones       False
# 4                      ALDO       False
# ..                      ...         ...
# 79           Isaac Dewhirst       False
# 80               WE Fashion       False
# 81                  DeFacto       False
# 82  KnowledgeCotton Apparel       False
# 83                    Blend       False
#
#                                       family_articles  \
# 0   [{'sku': 'TO222D0T6-K12', 'url_key': 'tom-tail...
# 1   [{'sku': 'TO722T03L-N11', 'url_key': 'tom-tail...
# 2   [{'sku': 'CB952L0I5-D11', 'url_key': 'icon-bra...
# 3   [{'sku': 'JA222O3EY-M11', 'url_key': 'jack-and...
# 4   [{'sku': 'A0112M02U-Q11', 'url_key': 'aldo-umi...
# ..                                                ...
# 79  [{'sku': 'DH022A036-K11', 'url_key': 'isaac-de...
# 80  [{'sku': 'WF522O0C9-M11', 'url_key': 'we-fashi...
# 81  [{'sku': 'DEZ22E088-Q11', 'url_key': 'defacto-...
# 82  [{'sku': 'KN222T00P-K11', 'url_key': 'knowledg...
# 83  [{'sku': 'BL522S050-C11', 'url_key': 'blend-sw...
#
#                                                 flags product_group  \
# 0   [{'key': 'discountRate', 'value': '-13%', 'tra...      clothing
# 1   [{'key': 'campaign', 'value': 'Prix Mini', 'tr...      clothing
# 2   [{'key': 'discountRate', 'value': '-30%', 'tra...   accessoires
# 3   [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
# 4   [{'key': 'discountRate', 'value': '-10%', 'tra...          shoe
# ..                                                ...           ...
# 79  [{'key': 'discountRate', 'value': '-50%', 'tra...      clothing
# 80  [{'key': 'discountRate', 'value': '-21%', 'tra...      clothing
# 81  [{'key': 'discountRate', 'value': '-33%', 'tra...      clothing
# 82  [{'key': 'discountRate', 'value': '-25%', 'tra...      clothing
# 83  [{'key': 'discountRate', 'value': '-10%', 'tra...      clothing
#
#    delivery_promises price.original price.promotional  \
# 0                 []       39,99  €          34,99  €
# 1                 []       79,99  €          69,99  €
# 2                 []       17,95  €          12,65  €
# 3                 []       12,99  €           9,74  €
# 4                 []       69,95  €          62,95  €
# ..               ...            ...               ...
# 79                []      119,95  €          59,95  €
# 80                []       14,00  €          11,00  €
# 81                []       44,99  €          29,99  €
# 82                []      119,95  €          89,95  €
# 83                []       34,95  €          31,45  €
#
#     price.has_different_prices  price.has_different_original_prices  \
# 0                        False                                False
# 1                        False                                False
# 2                        False                                False
# 3                        False                                False
# 4                        False                                False
# ..                         ...                                  ...
# 79                       False                                False
# 80                       False                                False
# 81                       False                                False
# 82                       False                                False
# 83                       False                                False
#
#     price.has_different_promotional_prices  \
# 0                                    False
# 1                                    False
# 2                                    False
# 3                                    False
# 4                                    False
# ..                                     ...
# 79                                   False
# 80                                   False
# 81                                   False
# 82                                   False
# 83                                   False
#
#     price.has_discount_on_selected_sizes_only condition condition_key
# 0                                       False       NaN           NaN
# 1                                       False       NaN           NaN
# 2                                       False       NaN           NaN
# 3                                       False       NaN           NaN
# 4                                       False       NaN           NaN
# ..                                        ...       ...           ...
# 79                                      False       NaN           NaN
# 80                                      False       NaN           NaN
# 81                                      False       NaN           NaN
# 82                                      False       NaN           NaN
# 83                                      False       NaN           NaN
#
# [84 rows x 19 columns]

# %%
#4. Let's find out the total page count in the 1st page data.
total_pages = results['pagination']['page_count']
total_pages
# Out:
# 428

# %%
#5. Now we will use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
df = pd.DataFrame()

for i in range(total_pages):
    k = 84*i
    url = f'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset={k}&sort=popularity'
    headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
    response = requests.get(url, headers = headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    try:
        flattened_data1=flattened_data1.set_index('sku')
        df = df.append(flattened_data1, sort = True)
    except:
        pass
# Out:
# <ipython-input-12-273fab34040f>:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# <ipython-input-12-273fab34040f>:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data1 = json_normalize(flattened_data.articles[0])

# %%
#6. Finally, let's print the data we just got. 
df
# Out:
#                amount            brand_name condition condition_key  \
# sku
# EL922E02M-C11     NaN               Ellesse       NaN           NaN
# EL912O02B-Q11     NaN               Ellesse       NaN           NaN
# C1822O08G-Q11     NaN    Calvin Klein Jeans       NaN           NaN
# AD122O0GM-Q11     NaN      adidas Originals       NaN           NaN
# PI922O0GS-A12     NaN              Pier One       NaN           NaN
# ...               ...                   ...       ...           ...
# MT352F00G-O11     NaN                Maître       NaN           NaN
# J1882H002-H11     NaN            JAPAN RAGS       NaN           NaN
# B1D32G00C-S13  236 ml  Baxter of California       NaN           NaN
# EA254H0W8-J11   215 g               Eastpak       NaN           NaN
# TO222D0RQ-A11     NaN            TOM TAILOR       NaN           NaN
#
#               delivery_promises  \
# sku
# EL922E02M-C11                []
# EL912O02B-Q11                []
# C1822O08G-Q11                []
# AD122O0GM-Q11                []
# PI922O0GS-A12                []
# ...                         ...
# MT352F00G-O11                []
# J1882H002-H11                []
# B1D32G00C-S13                []
# EA254H0W8-J11                []
# TO222D0RQ-A11                []
#
#                                                  family_articles  \
# sku
# EL922E02M-C11                                                 []
# EL912O02B-Q11                                                 []
# C1822O08G-Q11                                                 []
# AD122O0GM-Q11                                                 []
# PI922O0GS-A12                                                 []
# ...                                                          ...
# MT352F00G-O11  [{'sku': 'MT352F00G-O11', 'url_key': 'maitre-g...
# J1882H002-H11  [{'sku': 'J1882H002-H11', 'url_key': 'japan-ra...
# B1D32G00C-S13  [{'sku': 'B1D32G00C-S13', 'url_key': 'baxter-o...
# EA254H0W8-J11  [{'sku': 'EA254H0W8-J11', 'url_key': 'eastpak-...
# TO222D0RQ-A11  [{'sku': 'TO222D0RQ-A11', 'url_key': 'tom-tail...
#
#                                                            flags  is_premium  \
# sku
# EL922E02M-C11  [{'key': 'discountRate', 'value': '-20%', 'tra...       False
# EL912O02B-Q11  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# C1822O08G-Q11  [{'key': 'campaign', 'value': 'Prix Mini', 'tr...       False
# AD122O0GM-Q11  [{'key': 'discountRate', 'value': 'Jusqu’à -25...       False
# PI922O0GS-A12  [{'key': 'discountRate', 'value': '-15%', 'tra...       False
# ...                                                          ...         ...
# MT352F00G-O11  [{'key': 'discountRate', 'value': '-25%', 'tra...       False
# J1882H002-H11  [{'key': 'discountRate', 'value': '-50%', 'tra...       False
# B1D32G00C-S13  [{'key': 'discountRate', 'value': '-15%', 'tra...       False
# EA254H0W8-J11  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# TO222D0RQ-A11  [{'key': 'discountRate', 'value': '-25%', 'tra...       False
#
#                                                            media  \
# sku
# EL922E02M-C11  [{'path': 'spp-media-p1/6441bcc0deb1431db474e2...
# EL912O02B-Q11  [{'path': 'spp-media-p1/b47bfe8b01e044759ec60c...
# C1822O08G-Q11  [{'path': 'spp-media-p1/2a3975a0940739e29e5474...
# AD122O0GM-Q11  [{'path': 'spp-media-p1/48b9327c2f6433cc82cee6...
# PI922O0GS-A12  [{'path': 'spp-media-p1/6c55c6b371933a0fa209eb...
# ...                                                          ...
# MT352F00G-O11  [{'path': 'spp-media-p1/e72002a35be235188e28fa...
# J1882H002-H11  [{'path': 'spp-media-p1/03b63b3fd61943528e0319...
# B1D32G00C-S13  [{'path': 'spp-media-p1/0d2b846279623b23931149...
# EA254H0W8-J11  [{'path': 'spp-media-p1/680fedfd00c23f0da98d06...
# TO222D0RQ-A11  [{'path': 'spp-media-p1/15d72a5a188b3d308e3300...
#
#                                                             name  ...  \
# sku                                                               ...
# EL922E02M-C11  VELLIA JOG PANT - Pantalon de survêtement - gr...  ...
# EL912O02B-Q11            147 RUNNER - Baskets basses - black/red  ...
# C1822O08G-Q11     PUFF PRINT BACK LOGO - T-shirt imprimé - black  ...
# AD122O0GM-Q11                 TECH TEE - T-shirt imprimé - black  ...
# PI922O0GS-A12        5 PACK - T-shirt basique - white/blue/black  ...
# ...                                                          ...  ...
# MT352F00G-O11        GRUMBACH HAINER - Portefeuille - dark brown  ...
# J1882H002-H11                             Short de bain - orange  ...
# B1D32G00C-S13  INVIGORATING BODY WASH 236ML - Gel douche - bl...  ...
# EA254H0W8-J11      PINK CRUSHED - Sac bandoulière - pink crushed  ...
# TO222D0RQ-A11               Chemise - greenbluefilafilcheckgreen  ...
#
#               price.has_different_promotional_prices  \
# sku
# EL922E02M-C11                                  False
# EL912O02B-Q11                                  False
# C1822O08G-Q11                                  False
# AD122O0GM-Q11                                   True
# PI922O0GS-A12                                  False
# ...                                              ...
# MT352F00G-O11                                  False
# J1882H002-H11                                  False
# B1D32G00C-S13                                  False
# EA254H0W8-J11                                  False
# TO222D0RQ-A11                                  False
#
#               price.has_discount_on_selected_sizes_only  price.original  \
# sku
# EL922E02M-C11                                     False        49,95  €
# EL912O02B-Q11                                     False        79,95  €
# C1822O08G-Q11                                     False        50,00  €
# AD122O0GM-Q11                                     False        29,95  €
# PI922O0GS-A12                                     False        29,99  €
# ...                                                 ...             ...
# MT352F00G-O11                                     False        42,95  €
# J1882H002-H11                                     False        49,00  €
# B1D32G00C-S13                                     False        16,95  €
# EA254H0W8-J11                                     False        40,00  €
# TO222D0RQ-A11                                     False        39,99  €
#
#                price.promotional  product_group  \
# sku
# EL922E02M-C11           39,95  €       clothing
# EL912O02B-Q11           55,95  €           shoe
# C1822O08G-Q11           33,72  €       clothing
# AD122O0GM-Q11           22,45  €       clothing
# PI922O0GS-A12           25,59  €       clothing
# ...                          ...            ...
# MT352F00G-O11           32,00  €    accessoires
# J1882H002-H11           24,50  €     beach_wear
# B1D32G00C-S13           14,45  €         beauty
# EA254H0W8-J11           28,00  €    accessoires
# TO222D0RQ-A11           29,99  €       clothing
#
#                                                     sizes  \
# sku
# EL922E02M-C11                      [XS, S, M, L, XL, XXL]
# EL912O02B-Q11                [39, 41, 42, 43, 45, 46, 47]
# C1822O08G-Q11                               [S, M, L, XL]
# AD122O0GM-Q11                      [XS, S, M, L, XL, XXL]
# PI922O0GS-A12  [XS, S, M, L, XL, XXL, 3XL, 4XL, 5XL, 6XL]
# ...                                                   ...
# MT352F00G-O11                                  [One Size]
# J1882H002-H11                               [S, M, L, XL]
# B1D32G00C-S13                                          []
# EA254H0W8-J11                                  [One Size]
# TO222D0RQ-A11                                [44, 46, 50]
#
#                           tracking_information.impression_beacon  \
# sku
# EL922E02M-C11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# EL912O02B-Q11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# C1822O08G-Q11  https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# AD122O0GM-Q11                                                NaN
# PI922O0GS-A12                                                NaN
# ...                                                          ...
# MT352F00G-O11                                                NaN
# J1882H002-H11                                                NaN
# B1D32G00C-S13                                                NaN
# EA254H0W8-J11                                                NaN
# TO222D0RQ-A11                                                NaN
#
#                     tracking_information.metrigo_impression_urls  \
# sku
# EL922E02M-C11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# EL912O02B-Q11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# C1822O08G-Q11  [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# AD122O0GM-Q11                                                NaN
# PI922O0GS-A12                                                NaN
# ...                                                          ...
# MT352F00G-O11                                                NaN
# J1882H002-H11                                                NaN
# B1D32G00C-S13                                                NaN
# EA254H0W8-J11                                                NaN
# TO222D0RQ-A11                                                NaN
#
#               tracking_information.source  \
# sku
# EL922E02M-C11                         ccp
# EL912O02B-Q11                         ccp
# C1822O08G-Q11                         ccp
# AD122O0GM-Q11                         NaN
# PI922O0GS-A12                         NaN
# ...                                   ...
# MT352F00G-O11                         NaN
# J1882H002-H11                         NaN
# B1D32G00C-S13                         NaN
# EA254H0W8-J11                         NaN
# TO222D0RQ-A11                         NaN
#
#                                                          url_key
# sku
# EL922E02M-C11  ellesse-vellia-jog-pant-pantalon-de-survetemen...
# EL912O02B-Q11  ellesse-147-runner-baskets-basses-blackred-el9...
# C1822O08G-Q11  calvin-klein-jeans-puff-print-back-logo-t-shir...
# AD122O0GM-Q11  adidas-originals-tech-tee-t-shirt-imprime-ad12...
# PI922O0GS-A12  pier-one-5-pack-t-shirt-basique-whiteblueblack...
# ...                                                          ...
# MT352F00G-O11  maitre-grumbach-hainer-portefeuille-dark-brown...
# J1882H002-H11      japan-rags-short-de-bain-orange-j1882h002-h11
# B1D32G00C-S13  baxter-of-california-invigorating-body-wash-23...
# EA254H0W8-J11  eastpak-pink-crushed-sac-bandouliere-pink-crus...
# TO222D0RQ-A11  tom-tailor-chemise-greenbluefilafilcheckgreen-...
#
# [35952 rows x 24 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
#1. Extracting the trending brand from our df.
df.brand_name.value_counts().index[0]

# %%
#2. Extracting the product with the highest discount. 

#Our data is still text. Let's convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

#Defining a Discount Ammount Column to later examine which product has the highest discount. 
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

#Group our SKUs by the ammount of money discounted from the original price.
total_disc=df1.groupby(['name']).sum().discount_amount

# %%
#Sort every SKU by ascending order and show the article with the most discount applied to it. 
total_disc.sort_values(ascending=False).index[0]

# %%
#3. Getting the sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

#Let's first define a column named sum_discounted_prices.
sum_discounted_prices = df['price.promotional'].astype(float).sum()

#Then we'll define a column named sum_original_prices.
sum_original_prices = df['price.original'].astype(float).sum()

#Finally, let's make the ratio. 
ratio = sum_discounted_prices/sum_original_prices
print('The sum of discounts of all goods is: {:.2%}'.format(ratio))
