# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
# your code here
import json
import requests
import pandas as pd
from pandas import json_normalize

# %%
url = 'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset=84&sort=popularity'

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
# your code here
headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}
response = requests.get(url,headers=headers)
results = response.json()

# %%
flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1.shape
# Out:
# (84, 19)

# %%
total_pages = results['pagination']['page_count']

df = pd.DataFrame()

headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/84.0.4147.89 Safari/537.36'}

for i in range(total_pages):
    k = 84*i
    url = f'https://www.zalando.fr/api/catalog/articles?categories=promo-femme&limit=84&offset={k}&sort=popularity'
    
    try:
        response = requests.get(url, headers = headers)
        results = response.json()
        flattened_data = json_normalize(results)
        flattened_data1 = json_normalize(flattened_data.articles[0])

        flattened_data1=flattened_data1.set_index('sku')
        df = df.append(flattened_data1, sort = True)
    except:
        pass

# %%
df.head(10)
# Out:
#               amount        brand_name condition condition_key  \
# sku
# LE221G031-K11    NaN           Levi's®       NaN           NaN
# N1241E0XM-Q11    NaN  Nike Performance       NaN           NaN
# AN611N04J-O12    NaN        Anna Field       NaN           NaN
# EV451H0P5-B11    NaN          Even&Odd       NaN           NaN
# LA251H01P-K11    NaN           Lacoste       NaN           NaN
# AN621C1J3-I11    NaN        Anna Field       NaN           NaN
# AD122O0AO-G17    NaN  adidas Originals       NaN           NaN
# LA251H01P-K13    NaN           Lacoste       NaN           NaN
# EV421D1EY-Q11    NaN          Even&Odd       NaN           NaN
# EV421D1F4-A11    NaN          Even&Odd       NaN           NaN
#
#               delivery_promises family_articles  \
# sku
# LE221G031-K11                []              []
# N1241E0XM-Q11                []              []
# AN611N04J-O12                []              []
# EV451H0P5-B11                []              []
# LA251H01P-K11                []              []
# AN621C1J3-I11                []              []
# AD122O0AO-G17                []              []
# LA251H01P-K13                []              []
# EV421D1EY-Q11                []              []
# EV421D1F4-A11                []              []
#
#                                                            flags  is_premium  \
# sku
# LE221G031-K11  [{'key': 'discountRate', 'value': '-30%', 'tra...       False
# N1241E0XM-Q11  [{'key': 'discountRate', 'value': 'Jusqu’à -60...       False
# AN611N04J-O12  [{'key': 'discountRate', 'value': '-70%', 'tra...       False
# EV451H0P5-B11  [{'key': 'discountRate', 'value': '-70%', 'tra...       False
# LA251H01P-K11  [{'key': 'discountRate', 'value': '-25%', 'tra...       False
# AN621C1J3-I11  [{'key': 'discountRate', 'value': '-70%', 'tra...       False
# AD122O0AO-G17  [{'key': 'discountRate', 'value': 'Jusqu’à -30...       False
# LA251H01P-K13  [{'key': 'discountRate', 'value': '-31%', 'tra...       False
# EV421D1EY-Q11  [{'key': 'discountRate', 'value': '-60%', 'tra...       False
# EV421D1F4-A11  [{'key': 'discountRate', 'value': '-70%', 'tra...       False
#
#                                                            media  \
# sku
# LE221G031-K11  [{'path': 'LE/22/1G/03/1K/11/LE221G031-K11@4.j...
# N1241E0XM-Q11  [{'path': 'N1/24/1E/0X/MQ/11/N1241E0XM-Q11@10....
# AN611N04J-O12  [{'path': 'AN/61/1N/04/JO/12/AN611N04J-O12@12....
# EV451H0P5-B11  [{'path': 'EV/45/1H/0P/5B/11/EV451H0P5-B11@9.j...
# LA251H01P-K11  [{'path': 'LA/25/1H/01/PK/11/LA251H01P-K11@14....
# AN621C1J3-I11  [{'path': 'AN/62/1C/1J/3I/11/AN621C1J3-I11@12....
# AD122O0AO-G17  [{'path': 'AD/12/2O/0A/OG/17/AD122O0AO-G17@14....
# LA251H01P-K13  [{'path': 'LA/25/1H/01/PK/13/LA251H01P-K13@3.j...
# EV421D1EY-Q11  [{'path': 'EV/42/1D/1E/YQ/11/EV421D1EY-Q11@7.j...
# EV421D1F4-A11  [{'path': 'EV/42/1D/1F/4A/11/EV421D1F4-A11@7.j...
#
#                                                             name  ...  \
# sku                                                               ...
# LE221G031-K11  ORIGINAL TRUCKER - Veste en jean - soft as but...  ...
# N1241E0XM-Q11                      PEED - Collants - black/white  ...
# AN611N04J-O12                                  Bottines - cognac  ...
# EV451H0P5-B11                                   Pochette - beige  ...
# LA251H01P-K11                     NF1888PO_141 - Cabas - eclipse  ...
# AN621C1J3-I11                           Robe longue - pale mauve  ...
# AD122O0AO-G17  ADICOLOR 3STRIPES SHORT SLEEVE TEE - T-shirt i...  ...
# LA251H01P-K13               NF1888PO_141 - Cabas - illusion blue  ...
# EV421D1EY-Q11                  T-shirt à manches longues - black  ...
# EV421D1F4-A11            T-shirt à manches longues - white/black  ...
#
#               price.base_price price.has_different_original_prices  \
# sku
# LE221G031-K11              NaN                               False
# N1241E0XM-Q11              NaN                               False
# AN611N04J-O12              NaN                               False
# EV451H0P5-B11              NaN                               False
# LA251H01P-K11              NaN                               False
# AN621C1J3-I11              NaN                               False
# AD122O0AO-G17              NaN                               False
# LA251H01P-K13              NaN                               False
# EV421D1EY-Q11              NaN                               False
# EV421D1F4-A11              NaN                               False
#
#                price.has_different_prices  \
# sku
# LE221G031-K11                       False
# N1241E0XM-Q11                        True
# AN611N04J-O12                       False
# EV451H0P5-B11                       False
# LA251H01P-K11                       False
# AN621C1J3-I11                       False
# AD122O0AO-G17                        True
# LA251H01P-K13                       False
# EV421D1EY-Q11                       False
# EV421D1F4-A11                       False
#
#                price.has_different_promotional_prices  \
# sku
# LE221G031-K11                                   False
# N1241E0XM-Q11                                    True
# AN611N04J-O12                                   False
# EV451H0P5-B11                                   False
# LA251H01P-K11                                   False
# AN621C1J3-I11                                   False
# AD122O0AO-G17                                    True
# LA251H01P-K13                                   False
# EV421D1EY-Q11                                   False
# EV421D1F4-A11                                   False
#
#                price.has_discount_on_selected_sizes_only  price.original  \
# sku
# LE221G031-K11                                      False        119,95 €
# N1241E0XM-Q11                                      False         69,95 €
# AN611N04J-O12                                      False         29,99 €
# EV451H0P5-B11                                      False         19,99 €
# LA251H01P-K11                                      False         94,95 €
# AN621C1J3-I11                                      False         43,99 €
# AD122O0AO-G17                                      False         29,95 €
# LA251H01P-K13                                      False         95,00 €
# EV421D1EY-Q11                                      False         21,99 €
# EV421D1F4-A11                                      False         22,99 €
#
#               price.promotional product_group                     sizes  \
# sku
# LE221G031-K11           83,95 €      clothing    [XXS, XS, S, M, L, XL]
# N1241E0XM-Q11           27,95 €      clothing         [XS, S, M, L, XL]
# AN611N04J-O12            9,09 €          shoe  [36, 37, 38, 39, 40, 41]
# EV451H0P5-B11            5,99 €   accessoires                [One Size]
# LA251H01P-K11           70,95 €   accessoires                [One Size]
# AN621C1J3-I11           13,39 €      clothing         [XS, S, M, L, XL]
# AD122O0AO-G17           20,95 €      clothing                [S, L, XL]
# LA251H01P-K13           66,00 €   accessoires                [One Size]
# EV421D1EY-Q11            8,89 €      clothing                [XS, S, M]
# EV421D1F4-A11            6,99 €      clothing             [XS, S, M, L]
#
#                                                          url_key
# sku
# LE221G031-K11  levisr-original-trucker-veste-en-jean-soft-as-...
# N1241E0XM-Q11       nike-performance-peed-collants-n1241e0xm-q11
# AN611N04J-O12           anna-field-bottines-cognac-an611n04j-o12
# EV451H0P5-B11            evenandodd-pochette-beige-ev451h0p5-b11
# LA251H01P-K11       lacoste-cabas-penombre-eclipse-la251h01p-k11
# AN621C1J3-I11  anna-field-robe-de-cocktail-pale-mauve-an621c1...
# AD122O0AO-G17  adidas-originals-3-stripes-tee-t-shirt-imprime...
# LA251H01P-K13          lacoste-cabas-illusion-blue-la251h01p-k13
# EV421D1EY-Q11           evenandodd-debardeur-black-ev421d1ey-q11
# EV421D1F4-A11  evenandodd-t-shirt-a-manches-longues-whiteblac...
#
# [10 rows x 21 columns]

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
df.brand_name.value_counts().index[0]
# Out:
# 'Anna Field'

# %%
#Our data is still text. Convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

total_disc=df1.groupby(['brand_name']).sum().discount_amount

total_disc.sort_values(ascending=False).index[0]
# Out:
# 'usha'

# %%
sum_discounted_prices = df['price.promotional'].astype(float).sum()

sum_original_prices = df['price.original'].astype(float).sum()
 
discounts_of_all_goods  = sum_discounted_prices/sum_original_prices
discounts_of_all_goods
# Out:
# 0.6562972291720816
