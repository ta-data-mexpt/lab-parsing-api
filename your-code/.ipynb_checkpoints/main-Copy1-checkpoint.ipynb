# %% [markdown]
# # Challenge: Promotions
#
# In this challenge, you'll develop codes to parse and analyze data returned from another API on Zalando such as [Promos homme (Men's Promotions)
# ](https://www.zalando.fr/promo-homme/) or [Promos femme (Women's Promotions)](https://www.zalando.fr/promo-femme/). The workflow is almost the same as in the guided lesson but you'll work with different data.

# %% [markdown]
# ## Obtaining the link
#
# Wrote your codes in the cell below to obtain the data from the API endpoint you choose. A recap of the workflow:
#
# 1. Examine the webpages and choose one that you want to work with.
#
# 1. Use Google Chrome's DevTools to inspect the XHR network requests. Find out the API endpoint that serves data to the webpage.
#
# 1. Test the API endpoint in the browser to verify its data.
#
# 1. Change the page number offset of the API URL to test if it's working.

# %%
url = "https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset=0&sort=popularity"

# %% [markdown]
# ## Reading the data
#
# In the next cell, use Python to obtain data from the API endpoint you chose in the previous step. Workflow:
#
# 1. Import libraries.
#
# 1. Define the initial API endpoint URL.
#
# 1. Make request to obtain data of the 1st page. Flatten the data and store it in an empty object variable.
#
# 1. Find out the total page count in the 1st page data.
#
# 1. Use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
#
# 1. Print and review the data you obtained.

# %%
import json
import requests
import pandas as pd
from pandas.io.json import json_normalize

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}

# %%
#We already Imported the pertinent libraries above. Furthermore, initial API endpoint URL has been established as well.

#3. Now let's make a request to obtain data from the first page. 
response = requests.get(url,headers=headers)
results = response.json()

#Flattened data can be found here. 
flattened_data = json_normalize(results)
flattened_data1 = json_normalize(flattened_data.articles[0])
flattened_data1
# Out:
# <ipython-input-4-445650ea72f9>:8: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# <ipython-input-4-445650ea72f9>:9: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data1 = json_normalize(flattened_data.articles[0])
#               sku                                               name  \
# 0   HAA54K018-Q11       ONE VENM HYBRID - Lunettes de soleil - black
# 1   EL922E02M-C11  VELLIA JOG PANT - Pantalon de survêtement - gr...
# 2   C1822O08G-Q11     PUFF PRINT BACK LOGO - T-shirt imprimé - black
# 3   AD122O0GM-Q11                 TECH TEE - T-shirt imprimé - black
# 4   PI922O0GS-A12        5 PACK - T-shirt basique - white/blue/black
# ..            ...                                                ...
# 79  TO122F0BH-K12                            BROOKLYN - Short - blue
# 80  IJ022F01G-M11                            ALDRICH - Short - green
# 81  JA222E0D6-N11    JJIPAUL JJFLAKE  - Pantalon cargo - olive night
# 82  PI922PA0H-C11                                Polo - grey melange
# 83  LA212G005-Q11       CROCO SLIDE - Sandales de bain - black/white
#
#                                                 sizes  \
# 0                                          [One Size]
# 1                              [XS, S, M, L, XL, XXL]
# 2                                       [S, M, L, XL]
# 3                              [XS, S, M, L, XL, XXL]
# 4          [XS, S, M, L, XL, XXL, 3XL, 4XL, 5XL, 6XL]
# ..                                                ...
# 79           [28, 29, 30, 31, 32, 33, 34, 36, 38, 40]
# 80                            [S, M, L, XL, XXL, 3XL]
# 81  [27x30, 27x32, 28x30, 28x32, 29x30, 29x32, 29x...
# 82                   [XS, S, M, L, XL, XXL, 3XL, 5XL]
# 83                 [39.5, 40.5, 42, 43, 44.5, 46, 47]
#
#                                               url_key  \
# 0      hawkers-lunettes-de-soleil-black-haa54k018-q11
# 1   ellesse-vellia-jog-pant-pantalon-de-survetemen...
# 2   calvin-klein-jeans-puff-print-back-logo-t-shir...
# 3   adidas-originals-tech-tee-t-shirt-imprime-ad12...
# 4   pier-one-5-pack-t-shirt-basique-whiteblueblack...
# ..                                                ...
# 79  tommy-hilfiger-brooklyn-light-short-to122f0bh-k12
# 80         indicode-jeans-aldrich-short-ij022f01g-m11
# 81  jack-and-jones-jjipaul-jjflake-pantalon-cargo-...
# 82           pier-one-polo-grey-melange-pi922pa0h-c11
# 83            lacoste-croco-slide-mules-la212g005-q11
#
#                                                 media          brand_name  \
# 0   [{'path': 'spp-media-p1/06a4447aa0373891ae8bb9...             Hawkers
# 1   [{'path': 'spp-media-p1/6441bcc0deb1431db474e2...             Ellesse
# 2   [{'path': 'spp-media-p1/2a3975a0940739e29e5474...  Calvin Klein Jeans
# 3   [{'path': 'spp-media-p1/48b9327c2f6433cc82cee6...    adidas Originals
# 4   [{'path': 'spp-media-p1/6c55c6b371933a0fa209eb...            Pier One
# ..                                                ...                 ...
# 79  [{'path': 'spp-media-p1/d8d905727ade35b0b6275b...      Tommy Hilfiger
# 80  [{'path': 'spp-media-p1/a6f31942b7fe3106a992b7...      INDICODE JEANS
# 81  [{'path': 'spp-media-p1/bfb181ec7b1430c19254bc...        Jack & Jones
# 82  [{'path': 'spp-media-p1/e7c9c609bba03150abe745...            Pier One
# 83  [{'path': 'spp-media-p1/6d4f1736e73b36deace178...             Lacoste
#
#     is_premium                                    family_articles  \
# 0        False  [{'sku': 'HAA54K018-Q11', 'url_key': 'hawkers-...
# 1        False  [{'sku': 'EL922E02M-C11', 'url_key': 'ellesse-...
# 2        False  [{'sku': 'C1822O08G-Q11', 'url_key': 'calvin-k...
# 3        False  [{'sku': 'AD122O0GM-Q11', 'url_key': 'adidas-o...
# 4        False  [{'sku': 'PI922O0GS-A12', 'url_key': 'pier-one...
# ..         ...                                                ...
# 79       False  [{'sku': 'TO122F0BH-K12', 'url_key': 'tommy-hi...
# 80       False  [{'sku': 'IJ022F01G-M11', 'url_key': 'indicode...
# 81       False  [{'sku': 'JA222E0D6-N11', 'url_key': 'jack-and...
# 82       False  [{'sku': 'PI922PA0H-C11', 'url_key': 'pier-one...
# 83       False  [{'sku': 'LA212G005-Q11', 'url_key': 'lacoste-...
#
#                                                 flags product_group  ...  \
# 0   [{'key': 'discountRate', 'value': '-20%', 'tra...   accessoires  ...
# 1   [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing  ...
# 2   [{'key': 'campaign', 'value': 'Prix Mini', 'tr...      clothing  ...
# 3   [{'key': 'discountRate', 'value': 'Jusqu’à -25...      clothing  ...
# 4   [{'key': 'discountRate', 'value': '-15%', 'tra...      clothing  ...
# ..                                                ...           ...  ...
# 79  [{'key': 'discountRate', 'value': '-40%', 'tra...      clothing  ...
# 80  [{'key': 'discountRate', 'value': '-23%', 'tra...      clothing  ...
# 81  [{'key': 'discountRate', 'value': 'Jusqu’à -30...      clothing  ...
# 82  [{'key': 'discountRate', 'value': '-20%', 'tra...      clothing  ...
# 83  [{'key': 'discountRate', 'value': '-15%', 'tra...          shoe  ...
#
#    price.has_different_prices price.has_different_original_prices  \
# 0                       False                               False
# 1                       False                               False
# 2                       False                               False
# 3                        True                               False
# 4                       False                               False
# ..                        ...                                 ...
# 79                      False                               False
# 80                      False                               False
# 81                       True                               False
# 82                      False                               False
# 83                      False                               False
#
#    price.has_different_promotional_prices  \
# 0                                   False
# 1                                   False
# 2                                   False
# 3                                    True
# 4                                   False
# ..                                    ...
# 79                                  False
# 80                                  False
# 81                                   True
# 82                                  False
# 83                                  False
#
#    price.has_discount_on_selected_sizes_only  \
# 0                                      False
# 1                                      False
# 2                                      False
# 3                                      False
# 4                                      False
# ..                                       ...
# 79                                     False
# 80                                     False
# 81                                     False
# 82                                     False
# 83                                     False
#
#          tracking_information.metrigo_impression_urls  \
# 0   [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 1   [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 2   [https://ccp-et.adtechlab.zalan.do/event/sbv?z...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#                tracking_information.impression_beacon  \
# 0   https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 1   https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 2   https://ccp-et.adtechlab.zalan.do/event/sbv?z=...
# 3                                                 NaN
# 4                                                 NaN
# ..                                                ...
# 79                                                NaN
# 80                                                NaN
# 81                                                NaN
# 82                                                NaN
# 83                                                NaN
#
#     tracking_information.source  outfits  amount price.base_price
# 0                           ccp      NaN     NaN              NaN
# 1                           ccp      NaN     NaN              NaN
# 2                           ccp      NaN     NaN              NaN
# 3                           NaN      NaN     NaN              NaN
# 4                           NaN      NaN     NaN              NaN
# ..                          ...      ...     ...              ...
# 79                          NaN      NaN     NaN              NaN
# 80                          NaN      NaN     NaN              NaN
# 81                          NaN      NaN     NaN              NaN
# 82                          NaN      NaN     NaN              NaN
# 83                          NaN      NaN     NaN              NaN
#
# [84 rows x 25 columns]

# %%
print(request.json())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-26dc5bfe23a3> in <module>
# ----> 1 print(request.json())
#
# NameError: name 'request' is not defined

# %%
#4. Let's find out the total page count in the 1st page data.
total_pages = results['pagination']['page_count']
total_pages
# Out:
# 428

# %%
#5. Now we will use a FOR loop to make requests for the additional pages from 2 to page count. Append the data of each additional page to the flatterned data object.
df = pd.DataFrame()

for i in range(total_pages):
    k = 84*i
    url = f'https://www.zalando.fr/api/catalog/articles?categories=promo-homme&limit=84&offset={k}&sort=popularity'
    headers = {'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_4) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.138 Safari/537.36'}
    response = requests.get(url, headers = headers)
    results = response.json()
    flattened_data = json_normalize(results)
    flattened_data1 = json_normalize(flattened_data.articles[0])
    try:
        flattened_data1=flattened_data1.set_index('sku')
        df = df.append(flattened_data1, sort = True)
    except:
        pass
# Out:
# <ipython-input-7-273fab34040f>:10: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data = json_normalize(results)
# <ipython-input-7-273fab34040f>:11: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
#   flattened_data1 = json_normalize(flattened_data.articles[0])

# %%
#6. Finally, let's print the data we just got. 
df

# %% [markdown]
# ## Bonus
#
# Extract the following information from the data:
#
# * The trending brand.
#
# * The product(s) with the highest discount.
#
# * The sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

# %%
# your code here
#1. Extracting the trending brand from our df.
df.brand_name.value_counts().index[0]

# %%
#2. Extracting the product with the highest discount. 

#Our data is still text. Let's convert prices into numbers:
df['price.original']=df['price.original'].str.extract('(\d*,\d*)')
df['price.promotional']=df['price.promotional'].str.extract('(\d*,\d*)')

df['price.original'] = [x.replace(',', '.') for x in df['price.original']]
df['price.promotional'] = [x.replace(',', '.') for x in df['price.promotional']]

#Defining a Discount Ammount Column to later examine which product has the highest discount. 
df['discount_amount']=df['price.original'].astype(float)-df['price.promotional'].astype(float)
df1=df.copy()

#Group our SKUs by the ammount of money discounted from the original price.
total_disc=df1.groupby(['name']).sum().discount_amount

# %%
#Sort every SKU by ascending order and show the article with the most discount applied to it. 
total_disc.sort_values(ascending=False).index[0]

# %%
#3. Getting the sum of discounts of all goods (sum_discounted_prices divided by sum_original_prices).

#Let's first define a column named sum_discounted_prices.
sum_discounted_prices = df['price.promotional'].astype(float).sum()

#Then we'll define a column named sum_original_prices.
sum_original_prices = df['price.original'].astype(float).sum()

#Finally, let's make the ratio. 
ratio = sum_discounted_prices/sum_original_prices
print('The sum of discounts of all goods is: {:.2%}'.format(ratio))
